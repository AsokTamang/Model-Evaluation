# %%
import pandas as pd
import numpy as np
from utils import build_linear_nn_model, plot_loss_function
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import tensorflow as tf
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[26], line 3
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 from utils import build_linear_nn_model, plot_loss_function
#       4 from sklearn.preprocessing import StandardScaler, PolynomialFeatures
#       5 from sklearn.model_selection import train_test_split
#
# ImportError: cannot import name 'plot_loss_function' from 'utils' (C:\pythonprojects\Machine learning\model_evaluation\utils.py)

# %%
df =pd.read_csv('data/data_1.csv',header=None,names=['feature','target'])
df
# Out:
#         feature      target
# 0   1651.000000  432.645217
# 1   1691.816327  454.935530
# 2   1732.632653  471.525248
# 3   1773.448980  482.506389
# 4   1814.265306  468.357886
# 5   1855.081633  482.152531
# 6   1895.897959  540.021756
# 7   1936.714286  534.584267
# 8   1977.530612  558.346208
# 9   2018.346939  566.423445
# 10  2059.163265  581.397651
# 11  2099.979592  596.458737
# 12  2140.795918  596.714832
# 13  2181.612245  619.451390
# 14  2222.428571  616.576265
# 15  2263.244898  653.162460
# 16  2304.061224  666.519921
# 17  2344.877551  670.589759
# 18  2385.693878  669.022887
# 19  2426.510204  678.909323
# 20  2467.326531  707.436964
# 21  2508.142857  710.760288
# 22  2548.959184  745.191341
# 23  2589.775510  729.845762
# 24  2630.591837  743.802922
# 25  2671.408163  738.202691
# 26  2712.224490  772.946122
# 27  2753.040816  772.217706
# 28  2793.857143  784.213812
# 29  2834.673469  776.432608
# 30  2875.489796  804.776264
# 31  2916.306122  833.272459
# 32  2957.122449  825.690370
# 33  2997.938776  821.053325
# 34  3038.755102  833.822037
# 35  3079.571429  833.061422
# 36  3120.387755  825.698074
# 37  3161.204082  843.577337
# 38  3202.020408  869.395517
# 39  3242.836735  851.503015
# 40  3283.653061  863.182557
# 41  3324.469388  853.006013
# 42  3365.285714  877.156754
# 43  3406.102041  863.741996
# 44  3446.918367  874.671942
# 45  3487.734694  877.736336
# 46  3528.551020  874.112598
# 47  3569.367347  882.803295
# 48  3610.183673  910.832721
# 49  3651.000000  897.420463

# %%
X=np.array(df[['feature']])
Y= np.array(df['target'])

# %% [markdown]
# **Splitting the datas into train,test and cross_validation sets**

# %%
X_train,X_,Y_train,Y_ = train_test_split(X,Y,test_size=0.40,random_state=1)
X_cv,X_test,Y_cv,Y_test = train_test_split(X_,Y_,test_size=0.50,random_state=1)
del X_,Y_  #deleting the temporary variable
print(f'The number of training data set is: {X_train.shape[0]}')
print(f'The number of cross validation data set is: {X_cv.shape[0]}')
print(f'The number of test data set is: {X_test.shape[0]}')
# Out:
# The number of training data set is: 30
# The number of cross validation data set is: 10
# The number of test data set is: 10

# %% [markdown]
# **As we know in the neural network, the model learns the non_linear relationship by itself inside the algorithm, so no need for polynomial engineering**

# %% [markdown]
# **For training data**

# %%
pf = PolynomialFeatures(degree=1,include_bias=False)
X_mapped = pf.fit_transform(X_train)
sc = StandardScaler()
X_mapped_scaled = sc.fit_transform(X_mapped)
print(f'The scaled and engineered training data is: {X_mapped_scaled}')
# Out:
# The scaled and engineered training data is: [[ 1.42715997]
#  [-0.27691164]
#  [ 1.71117191]
#  [ 0.22010925]
#  [ 0.14910627]
#  [-1.19995042]
#  [ 0.8591361 ]
#  [-0.48992059]
#  [ 0.64612715]
#  [-0.77393252]
#  [ 0.50412118]
#  [ 1.64016892]
#  [ 0.93013909]
#  [-0.20590865]
#  [-0.06390269]
#  [ 0.29111223]
#  [-1.05794446]
#  [-0.98694147]
#  [ 1.85317788]
#  [-1.41295938]
#  [-0.34791462]
#  [-1.48396236]
#  [-0.4189176 ]
#  [-1.12894744]
#  [-0.70292954]
#  [-0.84493551]
#  [-0.91593849]
#  [-0.63192656]
#  [ 1.56916594]
#  [ 1.14314804]]

# %% [markdown]
# **For cross_validation data**

# %%
X_cv_mapped = pf.transform(X_cv)
X_cv_scaled = sc.transform(X_cv_mapped)
print(f'The scaled and engineered cross_validation data is: {X_mapped_scaled}')
# Out:
# The scaled and engineered cross_validation data is: [[ 1.42715997]
#  [-0.27691164]
#  [ 1.71117191]
#  [ 0.22010925]
#  [ 0.14910627]
#  [-1.19995042]
#  [ 0.8591361 ]
#  [-0.48992059]
#  [ 0.64612715]
#  [-0.77393252]
#  [ 0.50412118]
#  [ 1.64016892]
#  [ 0.93013909]
#  [-0.20590865]
#  [-0.06390269]
#  [ 0.29111223]
#  [-1.05794446]
#  [-0.98694147]
#  [ 1.85317788]
#  [-1.41295938]
#  [-0.34791462]
#  [-1.48396236]
#  [-0.4189176 ]
#  [-1.12894744]
#  [-0.70292954]
#  [-0.84493551]
#  [-0.91593849]
#  [-0.63192656]
#  [ 1.56916594]
#  [ 1.14314804]]

# %% [markdown]
# **For test datasets**

# %%
X_test_mapped = pf.transform(X_test)
X_test_scaled = sc.transform(X_test_mapped)
print(f'The scaled and engineered test data is: {X_test_scaled}')
# Out:
# The scaled and engineered test data is: [[ 1.21415102]
#  [ 1.99518384]
#  [ 1.92418086]
#  [ 0.78813312]
#  [ 1.35615699]
#  [-0.13490567]
#  [-1.34195639]
#  [ 0.36211522]
#  [ 0.57512417]
#  [ 1.00114207]]

# %% [markdown]
# **Evaluation of different neural network model based on the cost function of cross_validation datasets**

# %%
models = build_linear_nn_model()
nn_train_cf = []  #cost function based on the training dataset
nn_cv_cf = []     #cost function based on the cross_validation dataset
for model in models:
    model.compile(
    loss='mse',
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.1),
    )
    print(f'Training {model}')
    history = model.fit(X_mapped_scaled,Y_train,epochs = 300, verbose = 0)  #training the model
    plot_loss_function(history)
    print('Done\n')
    Y_train_prediction = model.predict(X_mapped_scaled)  #predicting the training dataset 
    mse_train = mean_squared_error(Y_train_prediction,Y_train)/2  #calculating the cost function based on training dataset
    nn_train_cf.append(mse_train)
    print(f'The cost function based on training dataset by {model} is: {mse_train}')

    Y_cv_prediction = model.predict(X_cv_scaled)  #predicting the cross_validation dataset
    mse_cv = mean_squared_error(Y_cv_prediction,Y_cv)/2  #cost function based on cross_validation dataset
    nn_cv_cf.append(mse_cv)
    print(f'The cost function based on cross_validation dataset by {model} is: {mse_cv}')
# Out:
# Training <Sequential name=model1, built=False>
# Done
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# The cost function based on training dataset by <Sequential name=model1, built=True> is: 73.39940617391844
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# The cost function based on cross_validation dataset by <Sequential name=model1, built=True> is: 113.01861746872979
# Training <Sequential name=model2, built=False>
# Done
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# The cost function based on training dataset by <Sequential name=model2, built=True> is: 406.19380888380334
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# The cost function based on cross_validation dataset by <Sequential name=model2, built=True> is: 551.7791780497818
# Training <Sequential name=model3, built=False>
# Done
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# The cost function based on training dataset by <Sequential name=model3, built=True> is: 406.1935076126476
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# The cost function based on cross_validation dataset by <Sequential name=model3, built=True> is: 551.7771277484643

# %%
print(f'The cost function based on training dataset, obtained from provided neural networks are: {nn_train_cf}')
print(f'The cost function based on cross_validation dataset, obtained from provided neural networks are: {nn_cv_cf}')
# Out:
# The cost function based on training dataset, obtained from provided neural networks are: [406.194094193488, 73.39642123740096, 406.1935673795797]
# The cost function based on cross_validation dataset, obtained from provided neural networks are: [551.7799379563178, 112.25866755618206, 551.7789536360731]

# %% [markdown]
# **Finding the best model based on the most minimum cost function of the cross_validation dataset**

# %%
req_index= np.argmin(nn_cv_cf)
best_model=models[req_index]
print(f'The best model is {best_model}')
# Out:
# The best model is <Sequential name=model2, built=True>

# %% [markdown]
# **Finding the cost function of the test dataset**

# %%
Y_test_prediction = best_model.predict(X_test_scaled)
mse_test = mean_squared_error(Y_test_prediction,Y_test)/2
print(f'The cost function of the test dataset is: {mse_test}')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# The cost function of the test dataset is: 131.54333983233644
